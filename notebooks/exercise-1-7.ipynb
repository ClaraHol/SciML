# %% [markdown]
# # Exercise 1.7

# %%
from sciml.data import Book_data
import numpy as np
import torch
from pathlib import Path
import os

# Go to parent directory
cwd = Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent)
    print(f"Changed current working directory to {cwd.parent}")
# Out:
# Changed current working directory to /home/clara/DTU/10. semester/SciML

# %%
data = Book_data.load_data("VORTALL")
print(data.mat)
# Out:
# tensor([[-9.3798e-15, -8.8137e-15, -8.9881e-15,  ..., -9.2319e-15,
#          -9.4149e-15, -9.3088e-15],
#         [-9.3066e-15, -8.8907e-15, -8.9440e-15,  ..., -9.3611e-15,
#          -9.5656e-15, -9.3589e-15],
#         [-9.4257e-15, -8.9483e-15, -9.0378e-15,  ..., -9.4682e-15,
#          -9.5340e-15, -9.5716e-15],
#         ...,
#         [-1.6701e-02, -1.7645e-02, -2.6512e-02,  ..., -1.2542e-01,
#          -6.7211e-02, -3.2942e-02],
#         [-3.0589e-02, -2.9936e-02, -3.5880e-02,  ..., -1.3964e-01,
#          -8.1968e-02, -4.7558e-02],
#         [-4.3867e-02, -4.1247e-02, -4.4027e-02,  ..., -1.5337e-01,
#          -9.6491e-02, -6.1892e-02]])
